# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df["Ram"]=df["Ram"].str.replace("GB","")
df["Weight"]=df["Weight"].str.replace("kg","")

# %%
df["Ram"]=df["Ram"].astype("int32")
df["Weight"]=df["Weight"].astype("float32")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.distplot(df["Price"])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3178995481.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])

# %%
df["Company"].value_counts().plot(kind="bar")
plt.show()

# %%
w=df["Company"].value_counts()
plt.bar(w.index,w.values)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Company"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df["TypeName"].value_counts().plot(kind="bar")
plt.show()

# %%
sns.barplot(x=df["TypeName"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df["Inches"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df["ScreenResolution"].unique()
# Out:
# array(['IPS Panel Retina Display 2560x1600', '1440x900',
#        'Full HD 1920x1080', 'IPS Panel Retina Display 2880x1800',
#        '1366x768', 'IPS Panel Full HD 1920x1080',
#        'IPS Panel Retina Display 2304x1440',
#        'IPS Panel Full HD / Touchscreen 1920x1080',
#        'Full HD / Touchscreen 1920x1080',
#        'Touchscreen / Quad HD+ 3200x1800',
#        'IPS Panel Touchscreen 1920x1200', 'Touchscreen 2256x1504',
#        'Quad HD+ / Touchscreen 3200x1800', 'IPS Panel 1366x768',
#        'IPS Panel 4K Ultra HD / Touchscreen 3840x2160',
#        'IPS Panel Full HD 2160x1440',
#        '4K Ultra HD / Touchscreen 3840x2160', 'Touchscreen 2560x1440',
#        '1600x900', 'IPS Panel 4K Ultra HD 3840x2160',
#        '4K Ultra HD 3840x2160', 'Touchscreen 1366x768',
#        'IPS Panel Full HD 1366x768', 'IPS Panel 2560x1440',
#        'IPS Panel Full HD 2560x1440',
#        'IPS Panel Retina Display 2736x1824', 'Touchscreen 2400x1600',
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df["Touchscreen"]=df["ScreenResolution"].apply(lambda x: 1 if "Touchscreen" in x else 0)

# %%
df.sample(5)
# Out:
#     Company     TypeName  Inches   ScreenResolution  \
# 738     MSI       Gaming    15.6  Full HD 1920x1080
# 297    Dell  Workstation    17.3  Full HD 1920x1080
# 127    Asus     Notebook    14.0           1366x768
# 609    Acer     Notebook    14.0           1366x768
# 669    Acer     Notebook    15.6           1366x768
#
#                                       Cpu  Ram                Memory  \
# 738           Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 297           Intel Core i7 7820HQ 2.9GHz   16             256GB SSD
# 127              AMD E-Series 6110 1.5GHz    4              64GB SSD
# 609  Intel Pentium Quad Core N3710 1.6GHz    4   128GB Flash Storage
# 669              Intel Core i3 6006U 2GHz    4             128GB SSD
#
#                          Gpu         OpSys  Weight        Price  Touchscreen
# 738  Nvidia GeForce GTX 1060    Windows 10    1.80  111593.8944            0
# 297      Nvidia Quadro M1200    Windows 10    3.42  153705.3408            0
# ...

# %%
df["Touchscreen"].value_counts()
# Out:
# Touchscreen
# 0    1111
# 1     192
# Name: count, dtype: int64

# %%
df["Touchscreen"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df["Touchscreen"],y=df["Price"])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df["ScreenResolution"]
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1298     IPS Panel Full HD / Touchscreen 1920x1080
# 1299    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                      1366x768
# 1301                                      1366x768
# 1302                                      1366x768
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df["IPS"]=df["ScreenResolution"].apply(lambda x : 1 if "IPS" in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
sns.barplot(x=df["IPS"],y=df["Price"])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df["ScreenResolution"].str.split()
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1298    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1299    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1300                                           [1366x768]
# 1301                                           [1366x768]
# 1302                                           [1366x768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df["ScreenResolution"].apply(lambda x : x.split())
# Out:
# 0                [IPS, Panel, Retina, Display, 2560x1600]
# 1                                              [1440x900]
# 2                                   [Full, HD, 1920x1080]
# 3                [IPS, Panel, Retina, Display, 2880x1800]
# 4                [IPS, Panel, Retina, Display, 2560x1600]
#                               ...
# 1298    [IPS, Panel, Full, HD, /, Touchscreen, 1920x1080]
# 1299    [IPS, Panel, Quad, HD+, /, Touchscreen, 3200x1...
# 1300                                           [1366x768]
# 1301                                           [1366x768]
# 1302                                           [1366x768]
# Name: ScreenResolution, Length: 1303, dtype: object

# %%
df["ScreenResolution"].str.split('x',n=1,expand=True)
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
new=df["ScreenResolution"].str.split('x',n=1,expand=True)

# %%
df["X_res"]=new[0]
df["Y_res"]=new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df["X_res"].str.replace(',','').str.findall(r"\b\d+\b")
# Out:
# 0       [2560]
# 1       [1440]
# 2       [1920]
# 3       [2880]
# 4       [2560]
#          ...
# 1298    [1920]
# 1299    [3200]
# 1300    [1366]
# 1301    [1366]
# 1302    [1366]
# Name: X_res, Length: 1303, dtype: object

# %%
df["X_res"]=df["X_res"].str.replace(',','').str.findall(r"\d+\.?\d+").apply(lambda x : x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df["X_res"]=df["X_res"].astype("int")
df["Y_res"]=df["Y_res"].astype("int")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df[["Ram","Weight","Touchscreen","IPS","X_res","Y_res","Price"]].corr()["Price"]
# Out:
# Ram            0.743007
# Weight         0.210370
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Price          1.000000
# Name: Price, dtype: float64

# %%
import math

# %%
df["ppi"]=(((df["X_res"]**2 + df["Y_res"]**2)**0.5)/df["Inches"]).astype("float")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df[["Inches","Ram","Weight","Touchscreen","IPS","X_res","Y_res","Price","ppi"]].corr()["Price"]
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Price          1.000000
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=["ScreenResolution","Inches"],inplace=True)

# %%
df["Cpu"].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df["Cpu Name"]=df["Cpu"].apply(lambda x :" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#    X_res  Y_res         ppi       Cpu Name
# ...

# %%
def fetch_preprocessor(text):
    if text=="Intel Core i5" or text=="Intel Core i7" or text=="Intel Core i3" :
        return text
    else:
        if(text.split()[0]=="Intel"):
            return "Other Intel Processor"
        else:
            return "AMD Processor"

# %%
df["CPU_brand"]=df["Cpu Name"].apply(fetch_preprocessor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df["CPU_brand"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='CPU_brand'>

# %%
sns.barplot(x=df["CPU_brand"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
df.drop(columns=["Cpu","Cpu Name","X_res","Y_res"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      CPU_brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
plt.show()

# %%
df["Memory"].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df["Gpu"].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["Gpu_brand"]=df["Gpu"].apply(lambda x : x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      CPU_brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#   Gpu_brand
# 0     Intel
# 1     Intel
# ...

# %%
df["Gpu_brand"].value_counts()
# Out:
# Gpu_brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df=df[df["Gpu_brand"]!="ARM"]

# %%
sns.barplot(x=df["Gpu_brand"],y=df["Price"],estimator=np.median)
# Out:
# <Axes: xlabel='Gpu_brand', ylabel='Price'>

# %%
df.drop(columns=["Gpu"],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1752234203.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Gpu"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory  OpSys  Weight        Price  \
# 0   Apple  Ultrabook    8            128GB SSD  macOS    1.37   71378.6832
# 1   Apple  Ultrabook    8  128GB Flash Storage  macOS    1.34   47895.5232
# 2      HP   Notebook    8            256GB SSD  No OS    1.86   30636.0000
# 3   Apple  Ultrabook   16            512GB SSD  macOS    1.83  135195.3360
# 4   Apple  Ultrabook    8            256GB SSD  macOS    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand Gpu_brand
# 0            0    1  226.983005  Intel Core i5     Intel
# 1            0    0  127.677940  Intel Core i5     Intel
# 2            0    0  141.211998  Intel Core i5     Intel
# 3            0    1  220.534624  Intel Core i7       AMD
# 4            0    1  226.983005  Intel Core i5     Intel

# %%
df["OpSys"].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df["OpSys"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
def cat_os(text):
    if text=="Windows 10" or text=="Windows 7" or text=="Windows 10 S":
        return "Windows"
    elif text== "macOS" or text=="Mac OS X":
        return "MAc"
    else:
        return "Other/No OS/Linux"

# %%
df["os"]=df["OpSys"].apply(cat_os)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3879185682.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["os"]=df["OpSys"].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory  OpSys  Weight        Price  \
# 0   Apple  Ultrabook    8            128GB SSD  macOS    1.37   71378.6832
# 1   Apple  Ultrabook    8  128GB Flash Storage  macOS    1.34   47895.5232
# 2      HP   Notebook    8            256GB SSD  No OS    1.86   30636.0000
# 3   Apple  Ultrabook   16            512GB SSD  macOS    1.83  135195.3360
# 4   Apple  Ultrabook    8            256GB SSD  macOS    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand Gpu_brand                 os
# 0            0    1  226.983005  Intel Core i5     Intel                MAc
# 1            0    0  127.677940  Intel Core i5     Intel                MAc
# 2            0    0  141.211998  Intel Core i5     Intel  Other/No OS/Linux
# 3            0    1  220.534624  Intel Core i7       AMD                MAc
# 4            0    1  226.983005  Intel Core i5     Intel                MAc

# %%
df.drop(columns=["OpSys"],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3299756208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["OpSys"],inplace=True)

# %%
sns.barplot(x=df["os"],y=df["Price"])
plt.xticks(rotation=90)
plt.show()

# %%
sns.scatterplot(x=df["Weight"],y=df["Price"])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory  Weight        Price  \
# 0   Apple  Ultrabook    8            128GB SSD    1.37   71378.6832
# 1   Apple  Ultrabook    8  128GB Flash Storage    1.34   47895.5232
# 2      HP   Notebook    8            256GB SSD    1.86   30636.0000
# 3   Apple  Ultrabook   16            512GB SSD    1.83  135195.3360
# 4   Apple  Ultrabook    8            256GB SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand Gpu_brand                 os
# 0            0    1  226.983005  Intel Core i5     Intel                MAc
# 1            0    0  127.677940  Intel Core i5     Intel                MAc
# 2            0    0  141.211998  Intel Core i5     Intel  Other/No OS/Linux
# 3            0    1  220.534624  Intel Core i7       AMD                MAc
# 4            0    1  226.983005  Intel Core i5     Intel                MAc

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
df["Memory"]=df["Memory"].astype(str).replace("\.0","",regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\2001228437.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df["Memory"]=df["Memory"].astype(str).replace("\.0","",regex=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\2001228437.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].astype(str).replace("\.0","",regex=True)

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid',
#        '512GB SSD +  1TB Hybrid', '256GB SSD +  1TB Hybrid'], dtype=object)

# %%
df["Memory"].str.replace("GB","")
# Out:
# 0                 128 SSD
# 1       128 Flash Storage
# 2                 256 SSD
# 3                 512 SSD
# 4                 256 SSD
#               ...
# 1298              128 SSD
# 1299              512 SSD
# 1300     64 Flash Storage
# 1301              1TB HDD
# 1302              500 HDD
# Name: Memory, Length: 1302, dtype: object

# %%
df["Memory"]=df["Memory"].str.replace("GB","")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4109044152.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].str.replace("GB","")

# %%
df["Memory"].unique()
# Out:
# array(['128 SSD', '128 Flash Storage', '256 SSD', '512 SSD', '500 HDD',
#        '256 Flash Storage', '1TB HDD', '32 Flash Storage',
#        '128 SSD +  1TB HDD', '256 SSD +  256 SSD', '64 Flash Storage',
#        '256 SSD +  1TB HDD', '256 SSD +  2TB HDD', '32 SSD', '2TB HDD',
#        '64 SSD', '1TB Hybrid', '512 SSD +  1TB HDD', '1TB SSD',
#        '256 SSD +  500 HDD', '128 SSD +  2TB HDD', '512 SSD +  512 SSD',
#        '16 SSD', '16 Flash Storage', '512 SSD +  256 SSD',
#        '512 SSD +  2TB HDD', '64 Flash Storage +  1TB HDD', '180 SSD',
#        '1TB HDD +  1TB HDD', '32 HDD', '1TB SSD +  1TB HDD',
#        '512 Flash Storage', '128 HDD', '240 SSD', '8 SSD', '508 Hybrid',
#        '512 SSD +  1TB Hybrid', '256 SSD +  1TB Hybrid'], dtype=object)

# %%
df["Memory"].str.replace("TB","000").unique()
# Out:
# array(['128 SSD', '128 Flash Storage', '256 SSD', '512 SSD', '500 HDD',
#        '256 Flash Storage', '1000 HDD', '32 Flash Storage',
#        '128 SSD +  1000 HDD', '256 SSD +  256 SSD', '64 Flash Storage',
#        '256 SSD +  1000 HDD', '256 SSD +  2000 HDD', '32 SSD', '2000 HDD',
#        '64 SSD', '1000 Hybrid', '512 SSD +  1000 HDD', '1000 SSD',
#        '256 SSD +  500 HDD', '128 SSD +  2000 HDD', '512 SSD +  512 SSD',
#        '16 SSD', '16 Flash Storage', '512 SSD +  256 SSD',
#        '512 SSD +  2000 HDD', '64 Flash Storage +  1000 HDD', '180 SSD',
#        '1000 HDD +  1000 HDD', '32 HDD', '1000 SSD +  1000 HDD',
#        '512 Flash Storage', '128 HDD', '240 SSD', '8 SSD', '508 Hybrid',
#        '512 SSD +  1000 Hybrid', '256 SSD +  1000 Hybrid'], dtype=object)

# %%
df["Memory"]=df["Memory"].str.replace("TB","000")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3157326229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Memory"]=df["Memory"].str.replace("TB","000")

# %%
new=df["Memory"].str.split('+',n=1,expand=True)

# %%
new[0].unique()
# Out:
# array(['128 SSD', '128 Flash Storage', '256 SSD', '512 SSD', '500 HDD',
#        '256 Flash Storage', '1000 HDD', '32 Flash Storage', '128 SSD ',
#        '256 SSD ', '64 Flash Storage', '32 SSD', '2000 HDD', '64 SSD',
#        '1000 Hybrid', '512 SSD ', '1000 SSD', '16 SSD',
#        '16 Flash Storage', '64 Flash Storage ', '180 SSD', '1000 HDD ',
#        '32 HDD', '1000 SSD ', '512 Flash Storage', '128 HDD', '240 SSD',
#        '8 SSD', '508 Hybrid'], dtype=object)

# %%
new[1].unique()
# Out:
# array([None, '  1000 HDD', '  256 SSD', '  2000 HDD', '  500 HDD',
#        '  512 SSD', '  1000 Hybrid'], dtype=object)

# %%
new.isnull().sum()
# Out:
# 0       0
# 1    1094
# dtype: int64

# %%
df["first"]=new[0]
df["first"]=df["first"].str.strip()
df["second"]=new[1]
#df["second"]=df["second"].str.strip()
df["Layer1HDD"]=df["first"].apply(lambda x : 1 if "HDD" in x else 0)
df["Layer1Flash_Storage"]=df["first"].apply(lambda x : 1 if "Flash Storage" in x else 0)
df["Layer1Hybrid"]=df["first"].apply(lambda x : 1 if "Hybrid" in x else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4114811700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"]=new[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4114811700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"]=df["first"].str.strip()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4114811700.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df["Layer1SDD"]=df["first"].apply(lambda x : 1 if "SSD" in x else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\422515429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer1SDD"]=df["first"].apply(lambda x : 1 if "SSD" in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  Weight        Price  \
# 0   Apple  Ultrabook    8            128 SSD    1.37   71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage    1.34   47895.5232
# 2      HP   Notebook    8            256 SSD    1.86   30636.0000
# 3   Apple  Ultrabook   16            512 SSD    1.83  135195.3360
# 4   Apple  Ultrabook    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand Gpu_brand                 os  \
# 0            0    1  226.983005  Intel Core i5     Intel                MAc
# 1            0    0  127.677940  Intel Core i5     Intel                MAc
# 2            0    0  141.211998  Intel Core i5     Intel  Other/No OS/Linux
# 3            0    1  220.534624  Intel Core i7       AMD                MAc
# 4            0    1  226.983005  Intel Core i5     Intel                MAc
#
#                first second  Layer1HDD  Layer1Flash_Storage  Layer1Hybrid  \
# ...

# %%
df["Layer1Flash_Storage"].value_counts()
# Out:
# Layer1Flash_Storage
# 0    1228
# 1      74
# Name: count, dtype: int64

# %%
df["Layer1HDD"].value_counts()
# Out:
# Layer1HDD
# 0    927
# 1    375
# Name: count, dtype: int64

# %%
df["Layer1Hybrid"].value_counts()
# Out:
# Layer1Hybrid
# 0    1292
# 1      10
# Name: count, dtype: int64

# %%
df["Layer1SDD"].value_counts()
# Out:
# Layer1SDD
# 1    843
# 0    459
# Name: count, dtype: int64

# %%
df["first"] = df["first"].str.replace(r"\D", "", regex=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1569325483.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"] = df["first"].str.replace(r"\D", "", regex=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  Weight        Price  \
# 0   Apple  Ultrabook    8            128 SSD    1.37   71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage    1.34   47895.5232
# 2      HP   Notebook    8            256 SSD    1.86   30636.0000
# 3   Apple  Ultrabook   16            512 SSD    1.83  135195.3360
# 4   Apple  Ultrabook    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand Gpu_brand                 os  \
# 0            0    1  226.983005  Intel Core i5     Intel                MAc
# 1            0    0  127.677940  Intel Core i5     Intel                MAc
# 2            0    0  141.211998  Intel Core i5     Intel  Other/No OS/Linux
# 3            0    1  220.534624  Intel Core i7       AMD                MAc
# 4            0    1  226.983005  Intel Core i5     Intel                MAc
#
#   first second  Layer1HDD  Layer1Flash_Storage  Layer1Hybrid  Layer1SDD
# ...

# %%
df["second"].fillna("0",inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4272033183.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["second"].fillna("0",inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4272033183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"].fillna("0",inplace=True)

# %%
df["Layer2SSD"]=df["second"].apply(lambda x : 1 if "SSD" in x else 0)
df["Layer2HDD"]=df["second"].apply(lambda x : 1 if "HDD" in x else 0)
df["Layer2Flash_Storage"]=df["second"].apply(lambda x : 1 if "Flash Storage" in x else 0)
df["Layer2Hybrid"]=df["second"].apply(lambda x : 1 if "Hybrid" in x else 0)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1520885873.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer2SSD"]=df["second"].apply(lambda x : 1 if "SSD" in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1520885873.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Layer2HDD"]=df["second"].apply(lambda x : 1 if "HDD" in x else 0)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1520885873.py:3: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  Weight        Price  \
# 0   Apple  Ultrabook    8            128 SSD    1.37   71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage    1.34   47895.5232
# 2      HP   Notebook    8            256 SSD    1.86   30636.0000
# 3   Apple  Ultrabook   16            512 SSD    1.83  135195.3360
# 4   Apple  Ultrabook    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand  ... first second Layer1HDD  \
# 0            0    1  226.983005  Intel Core i5  ...   128      0         0
# 1            0    0  127.677940  Intel Core i5  ...   128      0         0
# 2            0    0  141.211998  Intel Core i5  ...   256      0         0
# 3            0    1  220.534624  Intel Core i7  ...   512      0         0
# 4            0    1  226.983005  Intel Core i5  ...   256      0         0
#
#   Layer1Flash_Storage  Layer1Hybrid  Layer1SDD  Layer2SSD  Layer2HDD  \
# ...

# %%
df["Layer2HDD"].value_counts()
# Out:
# Layer2HDD
# 0    1100
# 1     202
# Name: count, dtype: int64

# %%
df["Layer2Hybrid"].value_counts()
# Out:
# Layer2Hybrid
# 0    1300
# 1       2
# Name: count, dtype: int64

# %%
df["Layer2SSD"].value_counts()
# Out:
# Layer2SSD
# 0    1298
# 1       4
# Name: count, dtype: int64

# %%
df["Layer2Flash_Storage"].value_counts()
# Out:
# Layer2Flash_Storage
# 0    1302
# Name: count, dtype: int64

# %%
df["second"]=df["second"].str.replace(r"\D","",regex=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\605942513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"]=df["second"].str.replace(r"\D","",regex=True)

# %%
df["first"]=df["first"].astype(int)
df["second"]=df["second"].astype(int)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3759587949.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["first"]=df["first"].astype(int)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3759587949.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["second"]=df["second"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Company              1302 non-null   object
#  1   TypeName             1302 non-null   object
#  2   Ram                  1302 non-null   int32
#  3   Memory               1302 non-null   object
#  4   Weight               1302 non-null   float32
#  5   Price                1302 non-null   float64
#  6   Touchscreen          1302 non-null   int64
#  7   IPS                  1302 non-null   int64
#  8   ppi                  1302 non-null   float64
#  9   CPU_brand            1302 non-null   object
#  10  Gpu_brand            1302 non-null   object
#  11  os                   1302 non-null   object
#  12  first                1302 non-null   int32
#  13  second               1302 non-null   int32
#  14  Layer1HDD            1302 non-null   int64
# ...

# %%
(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 1298       0
# 1299       0
# 1300       0
# 1301    1000
# 1302     500
# Length: 1302, dtype: int64

# %%
(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1298    0
# 1299    0
# 1300    0
# 1301    0
# 1302    0
# Length: 1302, dtype: int64

# %%
(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])
# Out:
# 0         0
# 1       128
# 2         0
# 3         0
# 4         0
#        ...
# 1298      0
# 1299      0
# 1300     64
# 1301      0
# 1302      0
# Length: 1302, dtype: int64

# %%
(df["first"]*df["Layer1SDD"]+df["second"]*df["Layer2SSD"])
# Out:
# 0       128
# 1         0
# 2       256
# 3       512
# 4       256
#        ...
# 1298    128
# 1299    512
# 1300      0
# 1301      0
# 1302      0
# Length: 1302, dtype: int64

# %%
df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SDD"]=(df["first"]*df["Layer1SDD"]+df["second"]*df["Layer2SSD"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3070892276.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3070892276.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SDD"]=(df["first"]*df["Layer1SDD"]+df["second"]*df["Layer2SSD"])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\3070892276.py:3: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#   Company   TypeName  Ram             Memory  Weight        Price  \
# 0   Apple  Ultrabook    8            128 SSD    1.37   71378.6832
# 1   Apple  Ultrabook    8  128 Flash Storage    1.34   47895.5232
# 2      HP   Notebook    8            256 SSD    1.86   30636.0000
# 3   Apple  Ultrabook   16            512 SSD    1.83  135195.3360
# 4   Apple  Ultrabook    8            256 SSD    1.37   96095.8080
#
#    Touchscreen  IPS         ppi      CPU_brand  ... Layer1Hybrid Layer1SDD  \
# 0            0    1  226.983005  Intel Core i5  ...            0         1
# 1            0    0  127.677940  Intel Core i5  ...            0         0
# 2            0    0  141.211998  Intel Core i5  ...            0         1
# 3            0    1  220.534624  Intel Core i7  ...            0         1
# 4            0    1  226.983005  Intel Core i5  ...            0         1
#
#    Layer2SSD  Layer2HDD  Layer2Flash_Storage  Layer2Hybrid  HDD  SDD  \
# ...

# %%
df.drop(columns=["Layer1Hybrid","Layer1SDD","Layer2SSD","Layer2HDD","Layer2Flash_Storage","Layer2Hybrid","Layer1HDD","Layer1Flash_Storage","first","second"],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\2130406864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Layer1Hybrid","Layer1SDD","Layer2SSD","Layer2HDD","Layer2Flash_Storage","Layer2Hybrid","Layer1HDD","Layer1Flash_Storage","first","second"],inplace=True)

# %%
df.drop(columns=["Memory"],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\1641139567.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Memory"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  IPS         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        CPU_brand Gpu_brand                 os  HDD  SDD  Flash_Storage  Hybrid
# 0  Intel Core i5     Intel                MAc    0  128              0       0
# 1  Intel Core i5     Intel                MAc    0    0            128       0
# 2  Intel Core i5     Intel  Other/No OS/Linux    0  256              0       0
# 3  Intel Core i7       AMD                MAc    0  512              0       0
# 4  Intel Core i5     Intel                MAc    0  256              0       0

# %%
df[["Ram","Weight","Touchscreen","IPS","HDD","SDD","Flash_Storage","Hybrid","ppi","Price"]].corr()
# Out:
#                     Ram    Weight  Touchscreen       IPS       HDD       SDD  \
# Ram            1.000000  0.383362     0.118875  0.207949  0.095808  0.603379
# Weight         0.383362  1.000000    -0.293004  0.018643  0.514147 -0.063818
# Touchscreen    0.118875 -0.293004     1.000000  0.148026 -0.208766  0.257577
# IPS            0.207949  0.018643     0.148026  1.000000 -0.093588  0.225311
# HDD            0.095808  0.514147    -0.208766 -0.093588  1.000000 -0.400750
# SDD            0.603379 -0.063818     0.257577  0.225311 -0.400750  1.000000
# Flash_Storage -0.059612 -0.179165    -0.020809  0.068616 -0.117165 -0.147407
# Hybrid         0.038409  0.095122    -0.039591 -0.022505 -0.076674 -0.059845
# ppi            0.305688 -0.321883     0.458571  0.299142 -0.294698  0.509437
# Price          0.742905  0.209867     0.192917  0.253320 -0.096891  0.670660
#
#                Flash_Storage    Hybrid       ppi     Price
# Ram                -0.059612  0.038409  0.305688  0.742905
# ...

# %%
df[["Ram","Weight","Touchscreen","IPS","HDD","SDD","Flash_Storage","Hybrid","ppi","Price"]].corr()["Price"]
# Out:
# Ram              0.742905
# Weight           0.209867
# Touchscreen      0.192917
# IPS              0.253320
# HDD             -0.096891
# SDD              0.670660
# Flash_Storage   -0.040067
# Hybrid           0.007942
# ppi              0.475368
# Price            1.000000
# Name: Price, dtype: float64

# %%
sns.heatmap(df[["Ram","Weight","Touchscreen","IPS","HDD","SDD","Flash_Storage","Hybrid","ppi","Price"]].corr())
# Out:
# <Axes: >

# %%
sns.distplot(df["Price"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\941010651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df.drop(columns=["Flash_Storage","Hybrid"],inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\2691753502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Flash_Storage","Hybrid"],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
x=df.drop(columns=["Price"])
y=np.log(df["Price"])

# %%
sns.distplot(np.log(df["Price"]))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14124\4139655757.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df["Price"]))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
x
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15,random_state=2)

# %%
x_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
x_test
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  IPS         ppi  \
# 248       HP            Notebook    4    1.49            0    1  165.632118
# 555     Asus            Notebook    4    2.00            0    0  100.454670
# 1251      HP            Notebook    4    1.86            0    0  100.454670
# 547   Lenovo            Notebook    4    2.15            0    0  141.211998
# 885       HP  2 in 1 Convertible    4    1.28            1    0  165.632118
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1129      HP              Gaming    8    3.35            0    1  127.335675
# 172   Lenovo            Notebook    4    2.20            0    0  100.454670
# 322     Asus            Notebook    8    2.00            0    0  157.350512
# 996       HP           Ultrabook    8    1.11            1    1  165.632118
# 470       HP  2 in 1 Convertible    8    1.29            1    1  331.264236
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.ensemble import BaggingRegressor
from xgboost import XGBRFRegressor

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")

# %%
step1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('col_tnf',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  [0, 1, 7, 8, 9])])

# %%
step2=LinearRegression()
Pipeline([("step1",step1),("step2",step2)])
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 7, 8, 9])])),
#                 ('step2', LinearRegression())])

# %%
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 7, 8, 9])])),
#                 ('step2', LinearRegression())])

# %%
y_predit=pipe.predict(x_test)

# %%
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8073277448418712, 0.2101782797642822)

# %%
pipe.score(x_test,y_test),pipe.score(x_train,y_train)
# Out:
# (0.8073277448418712, 0.8339749577750897)

# %%
np.exp(0.20)
# Out:
# 1.2214027581601699

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=Ridge(alpha=10)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.81273310313118, 0.20926802242583045)

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=Lasso(alpha=0.001)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8071853945317105, 0.21114361613472565)

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=KNeighborsRegressor(n_neighbors=4)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.7968777043247933, 0.19921227097915445)

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=DecisionTreeRegressor(max_depth=8)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8358761531366754, 0.1839691124957658)

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=SVR(kernel="rbf",C=10000,epsilon=0.1)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.808318090228966, 0.20239059427193437)

# %% [markdown]
# <h1>RandomForestRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2=RandomForestRegressor(n_estimators=200,max_features="sqrt",max_depth=20,min_samples_leaf=1,min_samples_split=2)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
print(r2_score(y_test,y_predit))
print(mean_absolute_error(y_test,y_predit))
print(pipe.score(x_test,y_test)*100)
print(pipe.score(x_train,y_train))
# Out:
# 0.9035701808590947
# 0.14513467794833562
# 90.35701808590947
# 0.9811803024586075

# %% [markdown]
# <h1>ExtraTreesRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2 = ExtraTreesRegressor(
    n_estimators=100,max_features="sqrt",max_depth=20,min_samples_leaf=1,min_samples_split=2
)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.9007619079220035, 0.1433810226610702)

# %% [markdown]
# <h1>BaggingRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2 = BaggingRegressor(
    estimator=ExtraTreesRegressor(
        n_estimators=100,
        random_state=3,
        max_features=0.75,
        max_depth=15
    ),
    max_samples=0.5,
    random_state=3
)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8801791870742249, 0.16495202592254116)

# %% [markdown]
# <h1>AdaBoostRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2 =AdaBoostRegressor(n_estimators=15,learning_rate=1.0)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.7873779481277778, 0.2336008930003408)

# %% [markdown]
# <h1>GradientBoostingRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2 =GradientBoostingRegressor(n_estimators=500)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8828525841121586, 0.1589979774694553)

# %% [markdown]
# <h1>XGBRFRegressor</h1>

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
step2 =XGBRFRegressor(n_estimators=46,max_depth=15,learning_rate=0.5)
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.6685803475749812, 0.2824271588807803)

# %% [markdown]
# <h1>VotingRegressor</h1>

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
lr=LinearRegression()
rf=RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=16)
gbdt=GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb=XGBRFRegressor(n_estimators=25,max_depth=5,learning_rate=0.5)
et=ExtraTreesRegressor(
    n_estimators=100,
    random_state=3,
    max_features=0.75,
    max_depth=16
)
step2 =VotingRegressor([('rf',rf),('gbdt',gbdt),('xgb',xgb),('et',et)],weights=[5,1,1,1])
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8843619125140518, 0.16330587792400614)

# %% [markdown]
# <h1>Stacking</h1>

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")
estimators=[
    ('rf',RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=16)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb',XGBRFRegressor(n_estimators=25,max_depth=5,learning_rate=0.5))
]
step2 =StackingRegressor(estimators=estimators,final_estimator=Ridge(alpha=100))
Pipeline([("step1",step1),("step2",step2)])
pipe=Pipeline([("step1",step1),("step2",step2)])
pipe.fit(x_train,y_train)
y_predit=pipe.predict(x_test)
r2_score(y_test,y_predit),mean_absolute_error(y_test,y_predit)
# Out:
# (0.8738685351629432, 0.17242184406615263)

# %%
step1=ColumnTransformer(transformers=[("col_tnf",OneHotEncoder(sparse_output=False,drop="first"),[0,1,7,8,9])],remainder="passthrough")

# Step 2: Define the model
rf = ExtraTreesRegressor(random_state=42)

# Step 3: Define the parameter grid
param_grid = {
    'n_estimators': [100, 200],                # Fewer options
    'max_depth': [10, 20],                    # Reduced range
    'max_features': ['sqrt', 0.8],            # Limited features
    'min_samples_split': [2, 5],              # Smaller range
    'min_samples_leaf': [1, 2]                # Fewer options
}

# Step 4: Create the pipeline
pipe = Pipeline([
    ("step1", step1),
    ("model", rf)
])

# Step 5: Apply GridSearchCV to the pipeline
grid_search = GridSearchCV(
    estimator=pipe,
    param_grid={"model__" + key: value for key, value in param_grid.items()},  # Prefix model parameters
    cv=5,
    scoring="r2",
    verbose=2,
    n_jobs=-1
)

# Step 6: Fit the pipeline
grid_search.fit(x_train, y_train)

# Step 7: Evaluate the pipeline
#y_pred = grid_search.predict(x_test)
y_pred = grid_search.best_estimator_.predict(x_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Best Parameters:", grid_search.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[324], line 22
#      16 pipe = Pipeline([
#      17     ("step1", step1),
#      18     ("model", rf)
#      19 ])
#      21 # Step 5: Apply GridSearchCV to the pipeline
# ---> 22 grid_search = GridSearchCV(
#      23     estimator=pipe,
#      24     param_grid={"model__" + key: value for key, value in param_grid.items()},  # Prefix model parameters
#      25     cv=5,
#      26     scoring="r2",
#      27     verbose=2,
#      28     n_jobs=-1
#      29 )
#      31 # Step 6: Fit the pipeline
#      32 grid_search.fit(x_train, y_train)
#
# NameError: name 'GridSearchCV' is not defined

# %%
import pickle

# %%
pickle.dump(df,open("df.pkl","wb"))
pickle.dump(pipe,open("pipe.pkl","wb"))

# %%
df

# %%
df["Company"].unique()
